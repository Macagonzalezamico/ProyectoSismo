# %%
import pandas as pd

# %%
noaa_df = pd.read_csv('earthquakes-2023-06-29_15-51-45_-0300.tsv', delimiter='\t')

# %%
pd.set_option('display.max_columns', None)

# %%
noaa_df
# Out:
#                      Search Parameters    Year    Mo    Dy    Hr    Mn   Sec  \
# 0   ["Year >= 1995","Country = JAPAN"]     NaN   NaN   NaN   NaN   NaN   NaN
# 1                                  NaN  1995.0   1.0  16.0  20.0  46.0  53.6
# 2                                  NaN  1995.0   4.0   1.0   3.0  49.0  33.5
# 3                                  NaN  1995.0  10.0  18.0  10.0  37.0  26.3
# 4                                  NaN  1995.0  10.0  19.0   2.0  41.0  36.1
# ..                                 ...     ...   ...   ...   ...   ...   ...
# 80                                 NaN  2019.0   6.0  18.0  13.0  22.0  19.0
# 81                                 NaN  2021.0   2.0  13.0  14.0   7.0  50.0
# 82                                 NaN  2021.0   3.0  20.0   9.0   9.0  43.0
# 83                                 NaN  2022.0   3.0  16.0  14.0  36.0  33.0
# 84                                 NaN  2023.0   5.0   5.0   5.0  42.0   4.0
#
# ...

# %%
noaa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 39 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Search Parameters                   1 non-null      object
#  1   Year                                84 non-null     float64
#  2   Mo                                  84 non-null     float64
#  3   Dy                                  84 non-null     float64
#  4   Hr                                  84 non-null     float64
#  5   Mn                                  84 non-null     float64
#  6   Sec                                 84 non-null     float64
#  7   Tsu                                 47 non-null     float64
#  8   Vol                                 5 non-null      float64
#  9   Location Name                       84 non-null     object
#  10  Latitude                            84 non-null     float64
# ...

# %%
noaa_df.describe()
# Out:
#               Year         Mo         Dy         Hr         Mn        Sec  \
# count    84.000000  84.000000  84.000000  84.000000  84.000000  84.000000
# mean   2007.571429   6.726190  15.988095  10.797619  28.666667  30.634524
# std       7.229934   3.272195   8.105470   6.910407  17.302645  16.362472
# min    1995.000000   1.000000   1.000000   0.000000   0.000000   0.800000
# 25%    2003.000000   4.000000  10.750000   5.000000  14.500000  18.900000
# 50%    2007.000000   7.000000  16.000000  10.000000  28.500000  28.550000
# 75%    2013.000000  10.000000  22.250000  17.000000  44.250000  43.725000
# max    2023.000000  12.000000  31.000000  23.000000  59.000000  59.200000
#
#                Tsu          Vol   Latitude   Longitude  ...  Total Missing  \
# count    47.000000     5.000000  84.000000   84.000000  ...            0.0
# mean   4066.425532  7052.200000  35.355131  138.814000  ...            NaN
# std    1497.097463  1089.077913   4.437715    4.798852  ...            NaN
# ...
